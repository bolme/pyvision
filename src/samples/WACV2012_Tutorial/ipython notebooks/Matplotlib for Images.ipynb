# %%
import pyvision as pvimport PILimport numpy as np

# %%
lena = pv.LENAlena_img = pv.Image(lena)

# %%
lena_PIL = lena_img.asPIL()

# %%
#we can use subplot for multiple output imagessubplot(221)x = imshow(lena_PIL)subplot(222)y = imshow(lena_PIL, origin="lower")  #specify origin to fix output

# %%
lena_np = lena_img.asMatrix2D()imshow(lena_np.T, cmap="gray")
# Out:
# &lt;matplotlib.image.AxesImage at 0x10bd9e850&gt;

# %%
#The following does NOT work for playing#a video with repeated calls to imshow.#There seems to be an inability to get#figure updates until the end of the loop.'''import timeiontaz_file = pv.TAZ_VIDEOvid = pv.Video(taz_file)for i,frame in enumerate(vid):    pimg = frame.asPIL()    imshow(pimg, origin="lower")    draw()    #print x'''
# Out:
# &apos;\nimport time\nion\ntaz_file = pv.TAZ_VIDEO\nvid = pv.Video(taz_file)\nfor i,frame in enumerate(vid):\n    pimg = frame.asPIL()\n    imshow(pimg, origin=&quot;lower&quot;)\n    draw()\n    #print x\n&apos;

# %%
from IPython.lib.display import YouTubeVideovid = YouTubeVideo("TXOR1-fZw64")display(vid)
# Out:
# &lt;IPython.lib.display.YouTubeVideo at 0x10b5a9c10&gt;
